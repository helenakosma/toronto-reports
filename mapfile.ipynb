# %%
import geopandas as gpd
import folium
from folium import plugins
import mapclassify
from matplotlib import pyplot as plt

# %%
m = folium.Map(
    location=[43.7, -79.4],  # Coordinates Toronto
    zoom_start=12,           # Initial zoom
    min_zoom=12,             # Prevent zooming out
    max_zoom=18,             # Prevent zooming in
    control_scale=True       # Shows scale bar
)

# Restrict panning to a bounding box
m.fit_bounds([[43.5, -79.6], [43.8, -79.2]])
m.options['maxBounds'] = [[43.58, -79.65], [43.82, -79.15]]

#folium.Marker (
    #location = [43.6426, -79.3871],
    #popup = "CN Tower",
    #icon = folium.Icon(color = "red", icon = "Tower")
#).add_to(m)

#m

m.fit_bounds([[43.5, -79.6], [43.8, -79.2]])
m.options['maxBounds'] = [[43.58, -79.65], [43.82, -79.15]]            

# m.add_child(folium.ClickForMarker(
#     "<b>New Point</b><br>Double-click to edit",
#     icon=folium.Icon(color='blue')
#     ))?????????dwadwadwaddddddddddwd

# folium.ClickForMarker(popup="<# b>HEY!</b><br>Wanna add a report??").add_to(m)
#  if we keep the line above two markers show up on the map after you drag it sooo i commented it out

toronto=[43.7, -79.4]
folium.Marker(location=toronto, icon=folium.Icon(color='orange', icon_color='red', icon='sun-o', prefix='fa'), popup='Visited Feb 2020', tooltip='Toronto').add_to(m)

eastYork=[43.691087, -79.328156]
folium.Marker(location=eastYork, icon=folium.Icon(color='red', icon_color='red', icon='sun-o', prefix='fa'), popup='Whagwan fham.', tooltip='East York').add_to(m)

# js = """
# map.on('click', function(e) {
#     var lat = e.latlng.lat;
#     var lng = e.latlng.lng;
#     alert("You clicked at Latitude: " + lat + ", Longitude: " + lng);
#     // Add a marker on the clicked position
#     var marker = L.marker([lat, lng]).addTo(map);
#     marker.bindPopup("Latitude: " + lat + "<br>Longitude: " + lng).openPopup();

#     // Retrieve the existing coordinates from localStorage
#     var coordinates = JSON.parse(localStorage.getItem("coordinates")) || [];

#     // Add the new coordinates
#     coordinates.push({lat: lat, lng: lng});

#     // Save the updated coordinates back to localStorage
#     localStorage.setItem("coordinates", JSON.stringify(coordinates));
# });
# """

js = f"""
// Wait for the map to be fully loaded
document.addEventListener('DOMContentLoaded', function() {{
    // Initialize storage with empty array if not exists
    if (!localStorage.getItem('coordinates')) {{
        localStorage.setItem('coordinates', JSON.stringify([]));
        console.log('Initialized empty coordinates storage');
    }}
    
    // Get the map instance
    var map;
    var maxRetries = 10;
    var retryCount = 0;
    
    function initMap() {{
        map = window.{m.get_name()};
        
         if (!map) {{
             if (retryCount < maxRetries) {{
                 retryCount++;
                 setTimeout(initMap, 100);
                 return;
             }}
             console.error('Failed to find map after', maxRetries, 'retries');
             return;
         }} 
        // might not need the part above?
        
        // Successfully got map instance
        console.log('Map initialized successfully');
        console.log('Current coordinates:', JSON.parse(localStorage.getItem('coordinates')));
        
        map.on('click', function(e) {{
            var coords = JSON.parse(localStorage.getItem('coordinates'));
            var newCoord = {{
                lat: e.latlng.lat.toFixed(6),
                lng: e.latlng.lng.toFixed(6),
                timestamp: new Date().toISOString()
            }};
            
            coords.push(newCoord);
            localStorage.setItem('coordinates', JSON.stringify(coords));
            
            // Add marker
            var marker = L.marker([newCoord.lat, newCoord.lng], {{draggable: true}}).addTo(map);
            marker.bindPopup('Added: ' + newCoord.lat + ', ' + newCoord.lng);
            
            console.log('New coordinate added:', newCoord);
            console.log('All coordinates:', coords);
        }});
    }}
    
    // Start initialization
    initMap();
}});
"""



m.get_root().html.add_child(folium.Element(f"<script>{js}</script>"))

m.save('mapfile.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebdfb659398c4a74fc73b4af7a6822a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;script&gt;
# // Wait for the map to be fully loaded
# document.addEventListener(&#x27;DOMContentLoaded&#x27;, function() {
#     // Initialize storage with empty array if not exists
#     if (!localStorage.getItem(&#x27;coordinates&#x27;)) {
#         localStorage.setItem(&#x27;coordinates&#x27;, JSON.stringify([]));
#         console.log(&#x27;Initialized empty coordinates storage&#x27;);
#     }
#
#     // Get the map instance
#     var map;
#     var maxRetries = 10;
#     var retryCount = 0;
#
#     function initMap() {
#         map = window.map_ebdfb659398c4a74fc73b4af7a6822a5;
#
#          if (!map) {
#              if (retryCount &lt; maxRetries) {
#                  retryCount++;
#                  setTimeout(initMap, 100);
#                  return;
#              }
#              console.error(&#x27;Failed to find map after&#x27;, maxRetries, &#x27;retries&#x27;);
#              return;
#          }
#         // might not need the part above?
#
#         // Successfully got map instance
#         console.log(&#x27;Map initialized successfully&#x27;);
#         console.log(&#x27;Current coordinates:&#x27;, JSON.parse(localStorage.getItem(&#x27;coordinates&#x27;)));
#
#         map.on(&#x27;click&#x27;, function(e) {
#             var coords = JSON.parse(localStorage.getItem(&#x27;coordinates&#x27;));
#             var newCoord = {
#                 lat: e.latlng.lat.toFixed(6),
#                 lng: e.latlng.lng.toFixed(6),
#                 timestamp: new Date().toISOString()
#             };
#
#             coords.push(newCoord);
#             localStorage.setItem(&#x27;coordinates&#x27;, JSON.stringify(coords));
#
#             // Add marker
#             var marker = L.marker([newCoord.lat, newCoord.lng], {draggable: true}).addTo(map);
#             marker.bindPopup(&#x27;Added: &#x27; + newCoord.lat + &#x27;, &#x27; + newCoord.lng);
#
#             console.log(&#x27;New coordinate added:&#x27;, newCoord);
#             console.log(&#x27;All coordinates:&#x27;, coords);
#         });
#     }
#
#     // Start initialization
#     initMap();
# });
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebdfb659398c4a74fc73b4af7a6822a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebdfb659398c4a74fc73b4af7a6822a5 = L.map(
#                 &quot;map_ebdfb659398c4a74fc73b4af7a6822a5&quot;,
#                 {
#                     center: [43.7, -79.4],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;maxBounds&quot;: [
# [
# 43.58,
# -79.65,
# ],
# [
# 43.82,
# -79.15,
# ],
# ],
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ebdfb659398c4a74fc73b4af7a6822a5);
#
#
#
#
#
#             var tile_layer_0b3a92cf8dd7508f9006c43e5aa52f43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 12,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b3a92cf8dd7508f9006c43e5aa52f43.addTo(map_ebdfb659398c4a74fc73b4af7a6822a5);
#
#
#             map_ebdfb659398c4a74fc73b4af7a6822a5.fitBounds(
#                 [[43.5, -79.6], [43.8, -79.2]],
#                 {}
#             );
#
#
#             map_ebdfb659398c4a74fc73b4af7a6822a5.fitBounds(
#                 [[43.5, -79.6], [43.8, -79.2]],
#                 {}
#             );
#
#
#             var marker_b2d45f1b451114b9610050afbc0e21dc = L.marker(
#                 [43.7, -79.4],
#                 {
# }
#             ).addTo(map_ebdfb659398c4a74fc73b4af7a6822a5);
#
#
#             var icon_63bfb14d37337ce5bc806b0a47b99154 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;sun-o&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dbe04c26116ffc93651242acdfe117bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32c8b827d280f8323377c7a55e280d96 = $(`&lt;div id=&quot;html_32c8b827d280f8323377c7a55e280d96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Visited Feb 2020&lt;/div&gt;`)[0];
#                 popup_dbe04c26116ffc93651242acdfe117bc.setContent(html_32c8b827d280f8323377c7a55e280d96);
#
#
#
#         marker_b2d45f1b451114b9610050afbc0e21dc.bindPopup(popup_dbe04c26116ffc93651242acdfe117bc)
#         ;
#
#
#
#
#             marker_b2d45f1b451114b9610050afbc0e21dc.bindTooltip(
#                 `&lt;div&gt;
#                      Toronto
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b2d45f1b451114b9610050afbc0e21dc.setIcon(icon_63bfb14d37337ce5bc806b0a47b99154);
#
#
#             var marker_b62536b3dab3bd3c0e8a30aed957576f = L.marker(
#                 [43.7, -79.4],
#                 {
# }
#             ).addTo(map_ebdfb
